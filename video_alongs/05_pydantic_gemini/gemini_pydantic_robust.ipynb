# %% [markdown]
# # Gemini pydantic more robust

# %%
from google import genai
from pydantic import BaseModel, Field

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents = "list a few asian soup recipes. a yummy description and a list of ingredients"
)

print(response.text)
# Out:
# Here are a few delicious Asian soup recipes, each with a yummy description and a list of ingredients!
#
# ---
#
# ### 1. Tom Yum Goong (Thai Hot and Sour Shrimp Soup)
#
# **Yummy Description:**
# Prepare your taste buds for an exhilarating journey! Tom Yum Goong is a vibrant, zesty Thai masterpiece that perfectly balances spicy, sour, and aromatic notes. Bursting with the exotic fragrance of lemongrass, galangal, and kaffir lime leaves, this hot and sour shrimp soup is a symphony of flavors. Each spoonful is a thrilling dance of chili heat, tangy lime, and savory shrimp, often accompanied by earthy mushrooms and fresh herbs. It's truly an addictive, wake-you-up-and-smell-the-flavor kind of soup!
#
# **Ingredients:**
# *   **Broth Base:**
#     *   4 cups chicken or shrimp stock
#     *   1 stalk lemongrass, bruised and cut into 2-inch pieces
#     *   1-inch piece galangal (or ginger), thinly sliced
#     *   3-4 kaffir lime leaves, torn
#     *   2-4 Thai bird's eye chilies, bruised or sliced (adjust to heat preference)
# *   **Main Ingredients:**
#     *   1 lb large shrimp (prawns), peeled and deveined (tails on or off)
#     *   1 cup straw mushrooms or oyster mushrooms, halved
#     *   1/2 cup cherry tomatoes, halved (optional)
# *   **Seasoning & Garnish:**
#     *   3-4 tablespoons fish sauce
#     *   3-4 tablespoons fresh lime juice
#     *   1-2 teaspoons Tom Yum paste (optional, for extra flavor/color)
#     *   1/2 teaspoon sugar (optional, to balance sourness)
#     *   Fresh cilantro, chopped (for garnish)
#     *   Chili oil (for extra heat, optional)
#
# ---
#
# ### 2. Vietnamese Pho Bo (Beef Noodle Soup)
#
# **Yummy Description:**
# A true culinary embrace, Vietnamese Pho Bo is a soul-warming noodle soup celebrated for its incredibly fragrant and deeply complex broth. This iconic dish features a meticulously slow-simmered beef broth infused with star anise, cinnamon, cloves, ginger, and charred onion. Ladled over slippery rice noodles and delicate slices of rare beef, it's served with a vibrant platter of fresh herbs like cilantro, basil, mint, bean sprouts, and lime wedges, allowing you to customize each comforting, aromatic bite. It's a symphony of subtle spices and fresh vibrancy that leaves you utterly satisfied.
#
# **Ingredients:**
# *   **For the Broth (the heart of Pho):**
#     *   3-4 lbs beef bones (knuckle, marrow, oxtail), blanched
#     *   1 large onion, halved and charred
#     *   4-inch piece ginger, halved and charred
#     *   3-4 star anise pods
#     *   1 cinnamon stick (3-inch)
#     *   5-6 whole cloves
#     *   1 black cardamom pod
#     *   1 tablespoon coriander seeds
#     *   1 teaspoon fennel seeds
#     *   1/4 cup fish sauce
#     *   1-2 tablespoons rock sugar (or granulated sugar)
#     *   Salt to taste
#     *   12-14 cups water
# *   **Main Ingredients:**
#     *   1 lb thin flat rice noodles (banh pho), cooked according to package
#     *   1 lb very thinly sliced raw beef (eye of round, flank steak, brisket, sirloin)
# *   **Garnishes & Accompaniments (essential!):**
#     *   Fresh bean sprouts
#     *   Fresh Thai basil leaves
#     *   Fresh mint leaves
#     *   Fresh cilantro, chopped
#     *   Lime wedges
#     *   Thinly sliced fresh red chilies (e.g., bird's eye)
#     *   Hoisin sauce
#     *   Sriracha hot sauce
#
# ---
#
# ### 3. Japanese Miso Soup
#
# **Yummy Description:**
# The quintessential Japanese comfort food, Miso Soup is a surprisingly simple yet profoundly satisfying bowl of umami goodness. This delicate, savory broth is made from dashi (a fish and kelp stock) and dissolved miso paste, creating a gentle, nuanced flavor. Typically adorned with cubes of silken tofu, delicate wakame seaweed, and often thinly sliced green onions, it's a warm, nourishing, and wonderfully light soup that accompanies nearly every Japanese meal, offering a moment of quiet, wholesome enjoyment.
#
# **Ingredients:**
# *   **Dashi (Japanese Stock):**
#     *   4 cups water
#     *   1 piece kombu (dried kelp), about 4x4 inches
#     *   1/2 cup katsuobushi (bonito flakes)
#     *   (Alternatively, use dashi powder mixed with water for convenience)
# *   **Main Ingredients:**
#     *   3-4 tablespoons miso paste (white/shiro miso for mild, red/aka miso for stronger flavor, or mixed)
#     *   6 oz silken tofu, cut into 1/2-inch cubes
#     *   1 tablespoon dried wakame seaweed, rehydrated and chopped if large
# *   **Garnish:**
#     *   2 green onions (scallions), thinly sliced
#
# ---
#
# ### 4. Chinese Hot and Sour Soup
#
# **Yummy Description:**
# Get ready for a bold, exhilarating experience with Chinese Hot and Sour Soup! This classic Szechuan-inspired creation is a tantalizing dance of flavors – famously tangy from rice vinegar, deliciously spicy from white pepper and chili oil, and rich with savory umami notes. The thick, comforting broth is brimming with a delightful medley of textures, typically featuring shredded pork (or tofu for vegetarian), earthy wood ear and shiitake mushrooms, crisp bamboo shoots, and silken ribbons of egg. It's a warming, invigorating soup that wakes up every corner of your palate!
#
# **Ingredients:**
# *   **Broth Base:**
#     *   6 cups chicken or vegetable broth
# *   **Main Ingredients:**
#     *   4 oz pork loin or firm tofu, shredded or thinly sliced
#     *   1/4 cup dried wood ear mushrooms, rehydrated and shredded
#     *   4-5 dried shiitake mushrooms, rehydrated, stems removed, and sliced
#     *   1/2 cup canned bamboo shoots, julienned
#     *   1/4 cup rehydrated dried lily flowers (optional), tied into knots
# *   **Flavoring:**
#     *   1/4 cup rice vinegar
#     *   2 tablespoons light soy sauce
#     *   1-2 tablespoons chili oil (adjust to heat preference)
#     *   1 tablespoon dark soy sauce (for color, optional)
#     *   1 teaspoon white pepper (key for the "hot" element!)
#     *   1 teaspoon sesame oil
# *   **Thickener & Binder:**
#     *   3 tablespoons cornstarch mixed with 1/4 cup water (cornstarch slurry)
#     *   2 large eggs, whisked
# *   **Garnish:**
#     *   2 green onions (scallions), thinly sliced
#
# ---

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents = "list a few asian soup recipes. a yummy description and a list of ingredients"
)

# %%
class Resepie(BaseModel):
    resepie_name: str
    description: str
    ingredients: list[str]

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents = "list a few asian soup recipes. a yummy description and a list of ingredients",
    config = {"response_mime_type": "application/json", "response_schema": list[Resepie]}
)

response.text
# Out:
# '[{"resepie_name":"Tom Yum Goong","description":"A classic Thai hot and sour soup, bursting with aromatic herbs like lemongrass, galangal, kaffir lime leaves, and a fiery kick from chili. It\'s typically made with succulent shrimp, mushrooms, and a squeeze of fresh lime juice, creating a symphony of vibrant flavors that\'s both invigorating and comforting.","ingredients":["Shrimp","Mushrooms","Lemongrass","Galangal","Kaffir lime leaves","Fish sauce","Lime juice","Chili paste","Chili peppers","Cilantro","Chicken broth"]},\n{"resepie_name":"Miso Ramen","description":"A deeply satisfying Japanese noodle soup featuring a rich miso-based broth, often simmered for hours to develop its complex umami flavors. It\'s typically topped with springy ramen noodles, tender chashu pork, a soft-boiled egg, nori, scallions, and bamboo shoots, creating a hearty and flavorful meal.","ingredients":["Ramen noodles","Miso paste","Chicken or pork broth","Chashu pork","Soft-boiled egg","Nori (seaweed)","Scallions","Bamboo shoots","Soy sauce","Mirin","Garlic","Ginger"]},\n{"resepie_name":"Pho Bo","description":"Vietnam\'s iconic beef noodle soup, renowned for its incredibly fragrant and clear broth, slow-simmered with charred onions, ginger, and warming spices like star anise, cloves, and cinnamon. Served with delicate rice noodles, thinly sliced beef, and a generous plate of fresh herbs and sprouts, it\'s a soul-warming and aromatic culinary experience.","ingredients":["Beef bones","Beef shank","Rice noodles","Onions","Ginger","Star anise","Cinnamon stick","Cloves","Cardamom pods","Fish sauce","Sugar","Bean sprouts","Basil","Mint","Lime wedges","Jalapeno"]}]'

# %%
resepies = response.parsed
len(resepies)
# Out:
# 3

# %%
resepies[0].description
# Out:
# "A classic Thai hot and sour soup, bursting with aromatic herbs like lemongrass, galangal, kaffir lime leaves, and a fiery kick from chili. It's typically made with succulent shrimp, mushrooms, and a squeeze of fresh lime juice, creating a symphony of vibrant flavors that's both invigorating and comforting."

# %%
resepies[0].resepie_name
# Out:
# 'Tom Yum Goong'

# %%
resepies[0].ingredients
# Out:
# ['Shrimp',
#  'Mushrooms',
#  'Lemongrass',
#  'Galangal',
#  'Kaffir lime leaves',
#  'Fish sauce',
#  'Lime juice',
#  'Chili paste',
#  'Chili peppers',
#  'Cilantro',
#  'Chicken broth']

# %% [markdown]
# ## Simulate house prices

# %%
from typing import Literal

class Home(BaseModel):
    price: int
    rent: int
    living_area: int
    rooms: int
    type: Literal["apartment", "house"]
    address: str

    

response = client.models.generate_content(
    model="gemini-2.5-pro",
    contents = """
    List 50 houses and apartments for sale in Stockholm, Sweden. With price, rent, living area in square meters, number of rooms, type (house or apartment), and address.
    all curency in SEK. Data should be simulated for swedish market.
""",
    config = {"response_mime_type": "application/json", "response_schema": list[Home]}
)

response.text
# Out:
# '[\n  {\n    "price": 6250000,\n    "rent": 3450,\n    "living_area": 68,\n    "rooms": 2,\n    "type": "apartment",\n    "address": "Hornsgatan 82, 118 21 Stockholm"\n  },\n  {\n    "price": 11950000,\n    "rent": 5800,\n    "living_area": 105,\n    "rooms": 4,\n    "type": "apartment",\n    "address": "Karlavägen 70, 114 59 Stockholm"\n  },\n  {\n    "price": 3100000,\n    "rent": 2100,\n    "living_area": 35,\n    "rooms": 1,\n    "type": "apartment",\n    "address": "Sankt Eriksgatan 95, 113 32 Stockholm"\n  },\n  {\n    "price": 14500000,\n    "rent": 6500,\n    "living_area": 180,\n    "rooms": 6,\n    "type": "house",\n    "address": "Äppelviksvägen 34, 167 53 Bromma"\n  },\n  {\n    "price": 7800000,\n    "rent": 4200,\n    "living_area": 85,\n    "rooms": 3,\n    "type": "apartment",\n    "address": "Odengatan 55, 113 22 Stockholm"\n  },\n  {\n    "price": 4995000,\n    "rent": 2900,\n    "living_area": 54,\n    "rooms": 2,\n    "type": "apartment",\n    "address": "Bergsgatan 41, 112 28 Stockholm"\n  },\n  {\n    "price": 25000000,\n    "rent": 8900,\n    "living_area": 190,\n    "rooms": 5,\n    "type": "apartment",\n    "address": "Strandvägen 21, 114 56 Stockholm"\n  },\n  {\n    "price": 17800000,\n    "rent": 7200,\n    "living_area": 220,\n    "rooms": 7,\n    "type": "house",\n    "address": "Vendevägen 14, 182 61 Djursholm"\n  },\n  {\n    "price": 5400000,\n    "rent": 3850,\n    "living_area": 72,\n    "rooms": 3,\n    "type": "apartment",\n    "address": "Folkungagatan 101, 116 30 Stockholm"\n  },\n  {\n    "price": 9200000,\n    "rent": 4500,\n    "living_area": 98,\n    "rooms": 4,\n    "type": "apartment",\n    "address": "Hantverkargatan 15, 112 21 Stockholm"\n  },\n  {\n    "price": 11500000,\n    "rent": 5900,\n    "living_area": 165,\n    "rooms": 5,\n    "type": "house",\n    "address": "Långsjövägen 58, 125 50 Älvsjö"\n  },\n  {\n    "price": 3950000,\n    "rent": 2550,\n    "living_area": 45,\n    "rooms": 2,\n    "type": "apartment",\n    "address": "Torsgatan 77, 113 37 Stockholm"\n  },\n  {\n    "price": 8100000,\n    "rent": 4100,\n    "living_area": 90,\n    "rooms": 3,\n    "type": "apartment",\n    "address": "Rörstrandsgatan 25, 113 40 Stockholm"\n  },\n  {\n    "price": 6800000,\n    "rent": 3600,\n    "living_area": 75,\n    "rooms": 3,\n    "type": "apartment",\n    "address": "Renstiernas gata 30, 116 31 Stockholm"\n  },\n  {\n    "price": 13900000,\n    "rent": 6800,\n    "living_area": 195,\n    "rooms": 6,\n    "type": "house",\n    "address": "Skogsviksvägen 22, 133 36 Saltsjöbaden"\n  },\n  {\n    "price": 2950000,\n    "rent": 1980,\n    "living_area": 28,\n    "rooms": 1,\n    "type": "apartment",\n    "address": "Dalagatan 4, 111 23 Stockholm"\n  },\n  {\n    "price": 15500000,\n    "rent": 7100,\n    "living_area": 140,\n    "rooms": 5,\n    "type": "apartment",\n    "address": "Grev Turegatan 18, 114 46 Stockholm"\n  },\n  {\n    "price": 9950000,\n    "rent": 5200,\n    "living_area": 110,\n    "rooms": 4,\n    "type": "apartment",\n    "address": "Norr Mälarstrand 64, 112 40 Stockholm"\n  },\n  {\n    "price": 10500000,\n    "rent": 5100,\n    "living_area": 155,\n    "rooms": 5,\n    "type": "house",\n    "address": "Bergviksvägen 41, 168 62 Bromma"\n  },\n  {\n    "price": 5850000,\n    "rent": 3300,\n    "living_area": 65,\n    "rooms": 2,\n    "type": "apartment",\n    "address": "Bondegatan 7, 116 26 Stockholm"\n  },\n  {\n    "price": 4300000,\n    "rent": 2800,\n    "living_area": 50,\n    "rooms": 2,\n    "type": "apartment",\n    "address": "Sveavägen 120, 113 50 Stockholm"\n  },\n  {\n    "price": 22000000,\n    "rent": 8500,\n    "living_area": 280,\n    "rooms": 8,\n    "type": "house",\n    "address": "Parkvägen 35, 181 31 Lidingö"\n  },\n  {\n    "price": 7150000,\n    "rent": 3950,\n    "living_area": 82,\n    "rooms": 3,\n    "type": "apartment",\n    "address": "Tomtebogatan 12, 113 38 Stockholm"\n  },\n  {\n    "price": 12800000,\n    "rent": 6200,\n    " ...

# %%
homes = response.parsed
len(homes)
# Out:
# 50

# %%
homes[0].price, homes[0].address
# Out:
# (6250000, 'Hornsgatan 82, 118 21 Stockholm')

# %%
homes[0].__dict__
# Out:
# {'price': 6250000,
#  'rent': 3450,
#  'living_area': 68,
#  'rooms': 2,
#  'type': 'apartment',
#  'address': 'Hornsgatan 82, 118 21 Stockholm'}

# %%
import pandas as pd

df = pd.DataFrame([home.__dict__ for home in homes])

df.head()
# Out:
#       price  rent  living_area  rooms       type  \
# 0   6250000  3450           68      2  apartment
# 1  11950000  5800          105      4  apartment
# 2   3100000  2100           35      1  apartment
# 3  14500000  6500          180      6      house
# 4   7800000  4200           85      3  apartment
#
#                                  address
# 0        Hornsgatan 82, 118 21 Stockholm
# 1        Karlavägen 70, 114 59 Stockholm
# 2  Sankt Eriksgatan 95, 113 32 Stockholm
# 3       Äppelviksvägen 34, 167 53 Bromma
# 4         Odengatan 55, 113 22 Stockholm

# %%
cheap_houses = df.query("price < 10_000_000 and type == 'house'")
cheap_houses
# Out:
#       price  rent  living_area  rooms   type                          address
# 24  9500000  4800          140      5  house  Bäckbornas väg 8, 168 64 Bromma

# %%
cheap_houses.to_csv("cheap_houses.csv", index=False)
