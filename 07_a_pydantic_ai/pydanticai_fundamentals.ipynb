# %% [markdown]
# # PydanticAI fundamentals

# %%
from pydantic_ai import Agent

agent = Agent(model="google-gla:gemini-2.5-flash")

result = await agent.run(" Give me a IT employee working in Sweden, no yapping just the result ")

result
# Out:
# AgentRunResult(output="**Name:** Anders Nilsson\n**Age:** 34\n**Role:** Senior DevOps Engineer\n**Company:** Klarna (Fintech)\n**Location:** Stockholm, Sweden\n\nAnders works in a cross-functional team, focusing on automating deployment pipelines, managing cloud infrastructure (AWS), and ensuring system reliability for Klarna's payment solutions. He typically cycles to their city-center office, enjoys a communal fika break with colleagues, and practices flexible working hours. In his free time, he's often out with his family, hiking in nearby nature reserves or enjoying the city's cultural offerings.")

# %%
print(result.output)
# Out:
# **Name:** Anders Nilsson
# **Age:** 34
# **Role:** Senior DevOps Engineer
# **Company:** Klarna (Fintech)
# **Location:** Stockholm, Sweden
#
# Anders works in a cross-functional team, focusing on automating deployment pipelines, managing cloud infrastructure (AWS), and ensuring system reliability for Klarna's payment solutions. He typically cycles to their city-center office, enjoys a communal fika break with colleagues, and practices flexible working hours. In his free time, he's often out with his family, hiking in nearby nature reserves or enjoying the city's cultural offerings.

# %% [markdown]
# ## Use pydantic to stucture output

# %%
from pydantic import BaseModel, Field
class Employee(BaseModel):
    name: str = Field(description="The full name of the employee")
    age: int = Field(gt = 17,lt= 67 ,description="The age of the employee")
    salary: int = Field(gt = 30_000, lt= 100_000, description="The monthly salary of the employee in SEK, the more sineor the higher salary")
    role: str = Field(description="The role of the employee in the company, allways include the level of seniority e.g. Junior, Mid, Senior")
    description: str = Field(description="A short description of the employee, max 20 words")

result = await agent.run(" Give me a data engineer working in Sweden, no yapping just the result", output_type=Employee)
result
# Out:
# AgentRunResult(output=Employee(name='Erik Johansson', age=30, salary=55000, role='Mid-level Data Engineer', description='Skilled in building and maintaining data pipelines and infrastructure, ensuring data quality and accessibility.'))

# %%
employee = result.output
employee
# Out:
# Employee(name='Erik Johansson', age=30, salary=55000, role='Mid-level Data Engineer', description='Skilled in building and maintaining data pipelines and infrastructure, ensuring data quality and accessibility.')

# %%
employee.description, employee.name
# Out:
# ('Skilled in building and maintaining data pipelines and infrastructure, ensuring data quality and accessibility.',
#  'Erik Johansson')

# %%
isinstance(employee, BaseModel)
# Out:
# True

# %%
employee.model_dump()
# Out:
# {'name': 'Erik Johansson',
#  'age': 30,
#  'salary': 55000,
#  'role': 'Mid-level Data Engineer',
#  'description': 'Skilled in building and maintaining data pipelines and infrastructure, ensuring data quality and accessibility.'}

# %%
print(employee.model_dump_json(indent=3))
# Out:
# {
#    "name": "Erik Johansson",
#    "age": 30,
#    "salary": 55000,
#    "role": "Mid-level Data Engineer",
#    "description": "Skilled in building and maintaining data pipelines and infrastructure, ensuring data quality and accessibility."
# }

# %% [markdown]
# ## Simulate 10 employee

# %%
result = await agent.run("give me 10 different IT employees working in Sweden, no yapping just the result", output_type=list[Employee])

result
# Out:
# AgentRunResult(output=[Employee(name='Astrid Lindgren', age=32, salary=55000, role='Mid-level Software Engineer', description='Experienced in Python and JavaScript development, focusing on backend systems and API integrations.'), Employee(name='Björn Borg', age=45, salary=85000, role='Senior DevOps Engineer', description='Specializes in cloud infrastructure, CI/CD pipelines, and ensuring system reliability and scalability.'), Employee(name='Carl Larsson', age=27, salary=40000, role='Junior Data Analyst', description='Eager to learn, proficient in SQL and basic data visualization tools, supporting business intelligence.'), Employee(name='Doris Dahl', age=38, salary=68000, role='Lead UI/UX Designer', description='Designs intuitive user experiences and interfaces, leading a small team of designers.'), Employee(name='Erik Johansson', age=50, salary=95000, role='Principal Solutions Architect', description='Provides strategic technical direction and designs complex enterprise-level software solutions.'), Employee(name='Fanny Åberg', age=29, salary=48000, role='Mid-level QA Engineer', description='Ensures software quality through meticulous testing and automated test script development.'), Employee(name='Gustav Vasa', age=42, salary=75000, role='Senior Cybersecurity Analyst', description='Protects systems and data from threats, implementing security protocols and incident response.'), Employee(name='Helena Bergström', age=35, salary=60000, role='Mid-level Data Scientist', description='Develops machine learning models and performs advanced statistical analysis for insights.'), Employee(name='Ingrid Bergman', age=55, salary=98000, role='IT Project Manager', description='Manages large-scale IT projects, ensuring timely delivery and stakeholder satisfaction.'), Employee(name='Johan Karlsson', age=30, salary=52000, role='Mid-level Full-stack Developer', description='Competent in both frontend and backend technologies, delivering complete web applications.')])

# %%
for employee in result.output:
    print(f"{employee.name} is {employee.age} years old and works as a {employee.role} earning {employee.salary} SEK per month.")
# Out:
# Astrid Lindgren is 32 years old and works as a Mid-level Software Engineer earning 55000 SEK per month.
# Björn Borg is 45 years old and works as a Senior DevOps Engineer earning 85000 SEK per month.
# Carl Larsson is 27 years old and works as a Junior Data Analyst earning 40000 SEK per month.
# Doris Dahl is 38 years old and works as a Lead UI/UX Designer earning 68000 SEK per month.
# Erik Johansson is 50 years old and works as a Principal Solutions Architect earning 95000 SEK per month.
# Fanny Åberg is 29 years old and works as a Mid-level QA Engineer earning 48000 SEK per month.
# Gustav Vasa is 42 years old and works as a Senior Cybersecurity Analyst earning 75000 SEK per month.
# Helena Bergström is 35 years old and works as a Mid-level Data Scientist earning 60000 SEK per month.
# Ingrid Bergman is 55 years old and works as a IT Project Manager earning 98000 SEK per month.
# Johan Karlsson is 30 years old and works as a Mid-level Full-stack Developer earning 52000 SEK per month.

# %% [markdown]
# ## More complex model

# %%
from typing import Literal

class Department(BaseModel):
    name: Literal["IT", "HR", "Marketing", "Sales", "Finance"] = Field(description="The name of the department")
    description: str = Field(description="A short description of the department")
    employees: list[Employee]

class Company(BaseModel):
    name: str = Field(description="The name of the company")
    departments: list[Department]
    description: str = Field(description="A short description of the company")


result = await agent.run(("give me 5 employees in ench department, give me the departments IT, HR, Marketing, Sales and Finance, no yapping just the result",
                         "company should be called CoolCompany and be based in Sweden and sell ice cream"),
                          output_type=Company)

result
# Out:
# AgentRunResult(output=Company(name='CoolCompany', departments=[Department(name='IT', description='Manages all technology and infrastructure within the company.', employees=[Employee(name='Alice Wonderland', age=45, salary=65000, role='Senior IT Architect', description='Oversees system architecture and technical strategy.'), Employee(name='Bob The Builder', age=32, salary=48000, role='Mid-level Software Developer', description='Develops and maintains company software solutions.'), Employee(name='Charlie Chaplin', age=25, salary=32000, role='Junior IT Support Technician', description='Provides first-line technical support to employees.'), Employee(name='Diana Prince', age=40, salary=62000, role='Senior Cyber Security Analyst', description='Protects company data and systems from threats.'), Employee(name='Eve Adams', age=35, salary=50000, role='Mid-level Database Administrator', description='Manages and maintains company databases.')]), Department(name='HR', description='Handles all human resources, recruitment, and employee relations.', employees=[Employee(name='Frank Ocean', age=48, salary=68000, role='Senior HR Director', description='Leads all human resources initiatives and strategies.'), Employee(name='Grace Kelly', age=30, salary=45000, role='Mid-level Recruitment Specialist', description='Manages the full recruitment cycle for new hires.'), Employee(name='Henry VIII', age=28, salary=31000, role='Junior HR Assistant', description='Supports HR team with administrative tasks and onboarding.'), Employee(name='Ivy League', age=42, salary=60000, role='Senior Compensation & Benefits Manager', description='Designs and implements employee compensation and benefits programs.'), Employee(name='Jack Sparrow', age=38, salary=47000, role='Mid-level Employee Relations Specialist', description='Addresses employee concerns and fosters positive workplace relations.')]), Department(name='Marketing', description="Promotes the company's products and manages brand image.", employees=[Employee(name='Karen Carpenter', age=40, salary=60000, role='Senior Marketing Manager', description='Develops and executes marketing strategies to promote products.'), Employee(name='Liam Neeson', age=33, salary=46000, role='Mid-level Digital Marketing Specialist', description='Manages online marketing campaigns and digital presence.'), Employee(name='Mia Farrow', age=26, salary=31000, role='Junior Social Media Coordinator', description='Creates content and manages social media channels.'), Employee(name='Nora Roberts', age=39, salary=58000, role='Senior Brand Strategist', description="Develops and maintains the company's brand identity and messaging."), Employee(name='Oliver Twist', age=31, salary=44000, role='Mid-level Content Creator', description='Produces engaging content for various marketing channels.')]), Department(name='Sales', description='Responsible for selling ice cream products and managing client relationships.', employees=[Employee(name='Peter Pan', age=44, salary=63000, role='Senior Head of Sales', description='Leads the sales team and drives revenue growth.'), Employee(name='Queen Elizabeth', age=36, salary=49000, role='Mid-level Key Account Manager', description='Manages relationships with major clients and expands sales.'), Employee(name='Roger Rabbit', age=29, salary=33000, role='Junior Sales Representative', description='Identifies new sales opportunities and supports client outreach.'), Employee(name='Sarah Connor', age=41, salary=61000, role='Senior Business Development Manager', description='Identifies and develops new business opportunities and partnerships.'), Employee(name='Tom Sawyer', age=34, salary=47000, role='Mid-level Sales Support Specialist', description='Provides administrative and operational support to the sales team.')]), Department(name='Finance', description='Manages all financial operations, budgeting, and accounting.', employees=[Employee(name='Uma Thurman', age=50, salary=75000, role='Senior Chief Financial Officer (CF ...

# %%
company = result.output

company.model_dump()
# Out:
# {'name': 'CoolCompany',
#  'departments': [{'name': 'IT',
#    'description': 'Manages all technology and infrastructure within the company.',
#    'employees': [{'name': 'Alice Wonderland',
#      'age': 45,
#      'salary': 65000,
#      'role': 'Senior IT Architect',
#      'description': 'Oversees system architecture and technical strategy.'},
#     {'name': 'Bob The Builder',
#      'age': 32,
#      'salary': 48000,
#      'role': 'Mid-level Software Developer',
#      'description': 'Develops and maintains company software solutions.'},
#     {'name': 'Charlie Chaplin',
#      'age': 25,
#      'salary': 32000,
#      'role': 'Junior IT Support Technician',
#      'description': 'Provides first-line technical support to employees.'},
#     {'name': 'Diana Prince',
#      'age': 40,
#      'salary': 62000,
#      'role': 'Senior Cyber Security Analyst',
#      'description': 'Protects company data and systems from threats.'},
#     {'name': 'Eve Adams',
#      'age': 35,
#      'salary': 50000,
#      'role': 'Mid-level Database Administrator',
#      'description': 'Manages and maintains company databases.'}]},
#   {'name': 'HR',
#    'description': 'Handles all human resources, recruitment, and employee relations.',
#    'employees': [{'name': 'Frank Ocean',
#      'age': 48,
#      'salary': 68000,
#      'role': 'Senior HR Director',
#      'description': 'Leads all human resources initiatives and strategies.'},
#     {'name': 'Grace Kelly',
#      'age': 30,
#      'salary': 45000,
#      'role': 'Mid-level Recruitment Specialist',
#      'description': 'Manages the full recruitment cycle for new hires.'},
#     {'name': 'Henry VIII',
#      'age': 28,
#      'salary': 31000,
#      'role': 'Junior HR Assistant',
#      'description': 'Supports HR team with administrative tasks and onboarding.'},
#     {'name': 'Ivy League',
#      'age': 42,
#      'salary': 60000,
#      'role': 'Senior Compensation & Benefits Manager',
#      'description': 'Designs and implements employee compensation and benefits programs.'},
#     {'name': 'Jack Sparrow',
#      'age': 38,
#      'salary': 47000,
#      'role': 'Mid-level Employee Relations Specialist',
#      'description': 'Addresses employee concerns and fosters positive workplace relations.'}]},
#   {'name': 'Marketing',
#    'description': "Promotes the company's products and manages brand image.",
#    'employees': [{'name': 'Karen Carpenter',
#      'age': 40,
#      'salary': 60000,
#      'role': 'Senior Marketing Manager',
#      'description': 'Develops and executes marketing strategies to promote products.'},
#     {'name': 'Liam Neeson',
#      'age': 33,
#      'salary': 46000,
#      'role': 'Mid-level Digital Marketing Specialist',
#      'description': 'Manages online marketing campaigns and digital presence.'},
#     {'name': 'Mia Farrow',
#      'age': 26,
#      'salary': 31000,
#      'role': 'Junior Social Media Coordinator',
#      'description': 'Creates content and manages social media channels.'},
#     {'name': 'Nora Roberts',
#      'age': 39,
#      'salary': 58000,
#      'role': 'Senior Brand Strategist',
#      'description': "Develops and maintains the company's brand identity and messaging."},
#     {'name': 'Oliver Twist',
#      'age': 31,
#      'salary': 44000,
#      'role': 'Mid-level Content Creator',
#      'description': 'Produces engaging content for various marketing channels.'}]},
#   {'name': 'Sales',
#    'description': 'Responsible for selling ice cream products and managing client relationships.',
#    'employees': [{'name': 'Peter Pan',
#      'age': 44,
#      'salary': 63000,
#      'role': 'Senior Head of Sales',
#      'description': 'Leads the sales team and drives revenue growth.'},
#     {'name': 'Queen Elizabeth',
#      'age': 36,
#      'salary': 49000,
#      'role': 'Mid-level Key Account Manager',
#      'description': 'Manages relationships with major clients and expands sales.'},
#     {'name': 'Roger Rabbit',
#      'age': 29,
#      'salary': 33000,
#      'role': 'Junior Sales Representative',
#      'description': 'Identifies new sales opportunities and supports client outreach.'},
#     {'name': 'Sarah Connor',
#      'age': 41,
#      'salary': 61000,
#      'role': 'Senior Business Development Manager',
#      'description': 'Identifies and develops new business opportunities and partnerships.'},
#     {'name': 'Tom Sawyer',
#      'age': 34,
#      'salary': 47000,
#      'role': 'Mid-level Sales Support Specialist',
#      'description': 'Provides administrative and operational support to the sales team.'}]},
#   {'name': 'Finance',
#    'description': 'Manages all financial operations, budgeting, and accounting.',
#    'employees': [{'name': 'Uma Thurman',
#      'age': 50,
#      'salary': 75000,
#      'role': 'Senior Chief Financial Officer (CFO)',
#      'description': 'Oversees all financial aspects and strategic financial planning.'},
#     {'name': 'Victor Frankenstein',
#      'age': 37,
#      'salary': 52000,
#      'role': 'Mid-level Accountant',
#      'description': 'Manages financial records, prepares statements, and handles audits.'},
#     {'name': 'Wendy Darling',
#      'age': 27,
#      'salary': 34000,
#      'role': 'Junior Finance Assistant',
#      'description': 'Assists with daily financial transactions and data entry.'},
#     {'name': 'Xavier Woods',
#      'age': 43,
#      'salary': 64000,
#      'role': 'Senior Financial Analyst',
#      'description': 'Analyzes financial data and provides insights for business decisions.'},
#     {'name': 'Yara Greyjoy',
#      'age': 30,
#      'salary': 48000,
#      'role': 'Mid-level Payroll Specialist',
#      'description': 'Manages employee payroll and ensures compliance with regulations.'}]}],
#  'description': 'A Swedish company selling delicious ice cream.'}

# %%
departments = [department.name for department in company.departments]
departments
# Out:
# ['IT', 'HR', 'Marketing', 'Sales', 'Finance']
